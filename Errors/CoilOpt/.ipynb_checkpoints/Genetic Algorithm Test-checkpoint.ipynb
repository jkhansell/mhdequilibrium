# %%
import imp 
import numpy as np 
import geneticalgorithm as ga
import matplotlib.pyplot as plt
imp.reload(ga)
# Out:
# <module 'geneticalgorithm' from 'C:\\Users\\Johansell Villalobos\\Estudiantes ITCR\\Team Channel - Top Secret\\Codes\\Johan\\MHD\\mhdequilibrium\\Errors\\CoilOpt\\geneticalgorithm.py'>

# %%
f = lambda x: (1-x[0])**2+50*(x[1]-x[0]**2)**2 #función de prueba Rosenbrock

# %%
I = [-3, 3]
x = np.linspace(I[0],I[1],num=100)
x,y = np.meshgrid(x,x)
p = np.array([x,y])
vals = f(p)

# %%
results = ga.GA(f, 5e-3, 7000, 2, 20, I, npop = 220, nkeep = 30)
xtemp, ytemp = results[2].T

print(results[1])
print("\n")
print(results[0])
print(results[0][0]**2)

# La función Rosebrock tiene mínimos globales en puntos que 
# tienen la forma (a, a^2) se puede ver que esto se cumple aproximadamente 
# para los puntos encontrados con el algoritmo genético.
# Out:
# hi
# 222
# 0.006317711329076092
#
#
# [0.92052049 0.8472381 ]
# 0.8473579673089363

# %%
plt.figure(figsize=(8,5), dpi=120)
plt.scatter(x,y,c=vals,cmap='jet')
plt.plot(xtemp,ytemp,color='white', marker='.')
plt.colorbar()
plt.show()

# %%
import geneticalgorithm2 as ga2
imp.reload(ga2)
# Out:
# <module 'geneticalgorithm2' from 'C:\\Users\\Johansell Villalobos\\Estudiantes ITCR\\Team Channel - Top Secret\\Codes\\Johan\\MHD\\mhdequilibrium\\Errors\\CoilOpt\\geneticalgorithm2.py'>

# %%
I = np.array([[-3,3],
              [-3,3]])
kfunc = lambda x: np.exp(-x)
genalg = ga2.GenAlg(f, I, 2, kfunc, 1.1, 1, 4, dpopsize=1)
bestpoint = genalg.GA()
# Out:
# Algorithm Start
# 1
# 2
# 3
# 2
# 4
# 5
# 2
# 3
# 2
# 4
# 5
# 2
# 3
# 2
# 4
# 5
# 2
# 3
# 2
# 4
# 5
# 2
# 3
# 2
# 4
# 5
# 2
# 1
# 2
# 3
# 2
# 4
# 5
# 2
# 1
# 2
# 3
# 2
# 4
# 5
# 2
# 1
# 2
# 3
# 2
# 4
# 5
# 2
# 1
# 2
# 3
# 2
# 4
# 5
# 2
# 1
# 2
# 3
# 2
# 4
# 5
# 2
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-e9b9f2b7229c> in <module>
#       3 kfunc = lambda x: np.exp(-x)
#       4 genalg = ga2.GenAlg(f, I, 2, kfunc, 1.1, 1, 4)
# ----> 5 bestpoint = genalg.GA()
#
# ~\Estudiantes ITCR\Team Channel - Top Secret\Codes\Johan\MHD\mhdequilibrium\Errors\CoilOpt\geneticalgorithm2.py in GA(self)
#     209                     self.epsilon = self.epsilon/self.Rred
#     210                     self.Ipopsize += -self.dpopsize
# --> 211                     pop, costs = self.initialization()
#     212
#     213             iters += 1
#
# ~\Estudiantes ITCR\Team Channel - Top Secret\Codes\Johan\MHD\mhdequilibrium\Errors\CoilOpt\geneticalgorithm2.py in initialization(self)
#     151
#     152     def initialization(self):
# --> 153         pop = self.pop_generation()     #Initialization
#     154         costs = self.cost_eval(pop)
#     155         indcost = np.argsort(costs)
#
# ~\Estudiantes ITCR\Team Channel - Top Secret\Codes\Johan\MHD\mhdequilibrium\Errors\CoilOpt\geneticalgorithm2.py in pop_generation(self)
#      51
#      52         pop = np.zeros((npop, ngenes))
# ---> 53         pop[0] = np.random.rand(ngenes)
#      54         i = 1
#      55         while i < npop:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# Out:
# array([1.95239722, 0.76432561])
