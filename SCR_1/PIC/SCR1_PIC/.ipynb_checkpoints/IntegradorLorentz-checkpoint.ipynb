# %%
import numpy as np
import matplotlib.pyplot as plt 
#import plotly.graph_objects as go

# %%
#Constants definition

R0 = 0.2477 #major axis
rm = 0.09
zm = 0.09
nr = 10
nphi = 100
nz = 100

dr = 2*rm/nr
dphi = 2*np.pi/nphi
dz = 2*zm/nz

# %%
class Particle(object):
    
    def __init__(self, name, mass, charge, init_pos, init_vel):
        self.name = name        
        self.mass = mass
        self.charge = charge
        self.pos = init_pos
        self.vel = init_vel
        self.KE = [0.5*self.mass*np.linalg.norm(self.vel)**2]
        
    def calc_KE(self):
        self.KE.append(0.5*self.mass*np.linalg.norm(self.vel)**2)

# %%
def updateVelocityBoris(Particle, dt, E, B):
    qm = Particle.charge/Particle.mass
    v_minus = Particle.vel + qm*E*dt/2
    
    t = qm*B*dt/2
    v_prime = v_minus + np.cross(v_minus,t)
    s = 2*t/(1+np.dot(t,t))
    v_plus = v_minus + np.cross(v_prime ,s)
    Particle.vel = v_plus + qm*E*dt 
    Particle.calc_KE()

# %%
E = np.array([0,0,0])
B = np.array([0.1,0,0])
init_pos = np.array([0,0,0])
init_vel = np.array([1,2,0])
dt = 5e-13
m_e= 9.10938356e-31
q_e = -1.60217662e-19

electron = Particle('e-',m_e,q_e,
                    init_pos, init_vel)

# %%
nSteps = 1000
positions = np.zeros((nSteps, 3))
velocities = np.zeros((nSteps, 3))
time = dt*np.linspace(0,dt*nSteps, nSteps)
positions[0] = electron.vel
velocities[0] = electron.pos


for i in range(1,nSteps):
    updateVelocityBoris(electron, dt, E, B)
    velocities[i] = electron.vel
    positions[i] = positions[i-1] + velocities[i]*dt

# %%
np.array(electron.KE).shape
# Out:
# array([[4.55469178e-31, 1.82187671e-30, 0.00000000e+00],
#        [4.55469178e-31, 1.82173582e-30, 1.40891568e-34],
#        [4.55469178e-31, 1.82131319e-30, 5.63522689e-34],
#        ...,
#        [4.55469178e-31, 1.14209587e-30, 6.79780844e-31],
#        [4.55469178e-31, 1.15755656e-30, 6.64320155e-31],
#        [4.55469178e-31, 1.17294096e-30, 6.48935754e-31]])

# %%
plt.scatter(positions[:,0], positions[:,1])
plt.show()
plt.scatter(positions[:,1], positions[:,2])
plt.show()
plt.scatter(positions[:,0], positions[:,2])
plt.show()
plt.scatter(np.array(electron.KE), time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-1625a5654f3b> in <module>
#       5 plt.scatter(positions[:,0], positions[:,2])
#       6 plt.show()
# ----> 7 plt.scatter(np.array(electron.KE), time)
#
# D:\Johansell\Miniconda\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# D:\Johansell\Miniconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\Johansell\Miniconda\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# D:\Johansell\Miniconda\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4439         y = np.ma.ravel(y)
#    4440         if x.size != y.size:
# -> 4441             raise ValueError("x and y must be the same size")
#    4442
#    4443         if s is None:
#
# ValueError: x and y must be the same size
